# %%
import sys
sys.path.append('../')

from io.radial_reader import RadialArchive

# Path to your ScanArchive folder
inpdir = "/mikLKS/bpt/data/head_motion_study_suma/volunteer_110924_2/hires_ute"

# Create the object
radial = RadialArchive(inpdir)

# Test just the archive-finding logic
print(radial._find_archive_file())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       1 import sys
#       2 sys.path.append('../')
# ----> 4 from io.radial_reader import RadialArchive
#       6 # Path to your ScanArchive folder
#       7 inpdir = "/mikLKS/bpt/data/head_motion_study_suma/volunteer_110924_2/hires_ute"
#
# ModuleNotFoundError: No module named 'io.radial_reader'; 'io' is not a package

# %%
# !pwd
# Out:
# /home/rinbha/Research/BPT_MOTUS/nonrigid-motion-bpt/examples
